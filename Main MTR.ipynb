# %%
"""
códigos identificados nos MTRs do IMA (2019-2024)
Fonte de informações dos códigos: IN 13/2012 IBAMA: https://www.ibama.gov.br/component/legislacao/?view=legislacao&legislacao=128945
RSU = 61 códigos
RSV = 23 códigos
RCC = 44 códigos
RSS = 32 códigos
RSB = 76 códigos (RSB=RSAE Planilha PERS)
RSI = 453 códigos
RST = 23 códigos
RSM = 22 códigos
RSA = 10 códigos
OUTROS = 30 Códigos
"""

# Resíduos Sólidos Urbano (RSU) e Resíduos Sólidos Públicos (RPU) - 1501, 1502, 1602, 1606, 1912 e 2001 & 2002, 2003 (exceto 20 03 04)      
rsu = (
    '150101-Embalagens de papel e cartão',
    '150102-Embalagens de plástico',
    '150104-Embalagens de metal',
    '150105-Embalagens longa-vida',
    '150106-Mistura de embalagens',
    '150107-Embalagens de vidro',
    '150109-Embalagens têxteis',
    '150110(*)-Embalagens de qualquer um dos tipos acima descritos contendo ou contaminadas por resíduos de substâncias perigosas',
    '150111(*)-Embalagens de metal, incluindo recipientes vazios sob pressão, com uma matriz porosa sólida perigosa (por exemplo amianto)',
    '150202(*)-Absorventes, materiais filtrantes (incluindo filtros de óleo não anteriormente especificados), panos de limpeza e vestuário de proteção, contaminados por substâncias perigosas',
    '150203-Absorventes, materiais filtrantes, panos de limpeza e vestuário de proteção não abrangidos em 15 02 02 (*)',  
    '160601(*)-Bateria e acumuladores elétricos à base de chumbo e seus resíduos, incluindo os plásticos provenientes da carcaça externa da bateria',
    '160602(*)-Bateria e acumuladores elétricos de niquel cádmio e seus resíduos',
    '160603(*)-Pilhas contendo mercúrio',
    '160604-Pilhas alcalinas - exceto 16 06 13 (*)',
    '160605-Outras pilhas, baterias e acumuladores',
    '160606(*)-Eletrólitos de pilhas e acumuladores recolhidos separadamente',
    '191201-Papel e cartão',
    '191202-Metais ferrosos',
    '191203-Metais não ferrosos',
    '191204-Plásticos',
    '191205-Vidro',
    '191208-Têxteis',
    '191209-Substancias minerais (por exemplo, areia, rochas)',
    '191210-Resíduos combustíveis (combustíveis derivados de resíduos)',
    '191211-Borrachas',
    '191212(*)-Outros resíduos (incluindo misturas de materiais) do tratamento mecânico de resíduos contendo substancias perigosas',
    '191213-Outros resíduos (incluindo misturas de materiais) do tratamento mecânico de resíduos não abrangidos em 19 12 12 (*)',    
    '200101-Papel e cartão',
    '200102-Vidro',
    '200108-Resíduos biodegradáveis de cozinha e cantinas',
    '200110-Roupas',
    '200111-Têxteis',
    '200113(*)-Solventes',
    '200114(*)-Ácidos',
    '200115(*)-Resíduos alcalinos',
    '200117(*)-Produtos químicos para fotografia',
    '200119(*)-Pesticidas',
    '200121(*)-Lâmpadas fluorescentes, de vapor de sódio e mercúrio e de luz mista',
    '200123(*)-Produtos eletroeletrônicos fora de uso contendo clorofluorcarbonetos',
    '200125-Óleos e gorduras vegetais alimentares',
    '200126(*)-Óleos e gorduras não abrangidas em 20 01 25',
    '200127(*)-Tintas, produtos adesivos, colas e resinas contendo substancias perigosas',
    '200128-Tintas, produtos adesivos, colas e resinas não abrangidas em 20 01 27 (*)',
    '200129(*)-Detergentes contendo substancias perigosas',
    '200130-Detergentes não abrangidos em 20 01 29 (*)',
    '200131(*)-GRUPO B - Medicamentos citotóxicos e  citostáticos (Grupo B - ANVISA  222/18)',
    '200132-GRUPO B - Medicamentos não abrangidos em 20 01 31 (*) - (Grupo B - ANVISA  222/18)',
    '200133(*)-Pilhas e acumuladores abrangidos em 16 06 01 (*) ou 16 06 03 (*) e pilhas e acumuladores não separados contendo essas pilhas ou acumuladores',
    '200134-Pilhas e acumuladores não abrangidos em 20 01 33 (*)',
    '200139-Plásticos',
    '200140-Metais',
    '200141-Resíduos da limpeza de chaminés',
    '200199-Outras frações não anteriormente especificadas',    
    '200201-Resíduos de varrição,  limpeza de logradouros e vias públicas e outros serviços de limpeza urbana biodegradáveis',
    '200202-Terras e pedras',
    '200203-Outros resíduos de varrição,  limpeza de logradouros e vias públicas e outros serviços de limpeza urbana não biodegradáveis',    
    '200301-Outros resíduos urbanos e equiparados, incluindo misturas de resíduos',
    '200302-Resíduos de mercados públicos e feiras',
    '200303-Resíduos da limpeza de ruas e de galerias de drenagem pluvial',
    '200306-Resíduos de limpeza de esgotos, bueiros e bocas de lobo',
)

# Resíduo Sólido Volumoso (RSV)
rsv = (
	'150103-Embalagens de madeira',
	'160123-Pneus inservíveis/usados aeronáuticos',
	'160124-Pneus inservíveis/usados de automóveis',
	'160125-Pneus inservíveis/usados de bicicletas',
	'160126-Pneus inservíveis/usados de caminhões e ônibus',
	'160127-Pneus inservíveis/usados de motocicletas',
	'160128-Pneus inservíveis/usados de tratores',
	'160129-Pneus inservíveis/usados outras aplicações',
	'160209(*)-Transformadores, capacitores e demais equipamentos elétricos contendo PCB',
	'160210(*)-Equipamento fora de uso contendo ou contaminado por PCB não abrangido em 16 02 09 (*)',
	'160211(*)-Equipamento fora de uso contendo clorofluorcarbonetos, HCFC, HFC',
	'160212(*)-Equipamento fora de uso contendo amianto livre',
	'160213(*)-Equipamento fora de uso contendo componentes perigosos não abrangidos em 16 02 09 (*) a 16 02 12 (*)',
	'160214-Equipamento fora de uso não abrangidos em 16 02 09 (*) a 16 02 13 (*)',
	'160215(*)-Componentes perigosos retirados de equipamento fora de uso',
	'160216-Componentes retirados de equipamento fora de uso não abrangidos em 13 02 15 (*)',
	'191206(*)-Madeira contendo substancias perigosas',
	'191207-Madeira não abrangidas em 19 12 06 (*)',
	'200135(*)-Produtos eletroeletrônicos e seus componentes fora de uso não abrangido em 20 01 21 (*) ou 20 01 23 (*) contendo componentes perigosos (6)',
	'200136-Produtos eletroeletrônicos e seus componentes fora de uso não abrangido em 20 01 21 (*), 20 01 23 (*) ou 20 01 35 (*)',
	'200137(*)-Madeira contendo substancias perigosas',
 	'200138-Madeira não abrangida em 20 01 37 (*)',
 	'200399-Resíduos urbanos e equiparados não anteriormente especificados,'
)

# Resíduos Sólidos de Construção Civil (RCC)
rcc = (
    '170405-Ferro e aço (Classe B conforme Resolução CONAMA 307/02)',
    '170406-Estanho (Classe B conforme Resolução CONAMA 307/02)',
    '170407-Mistura de sucatas (Classe B conforme Resolução CONAMA 307/02)',
    '170409(*)-Resíduos metálicos contaminados com substâncias perigosas (Classe D conforme Resolução CONAMA 307/02)',
    '170411-Cabos não abrangidos em 17 04 10 (*) (Classe B conforme Resolução CONAMA 307/02)',
    '170412-Magnésio (Classe B conforme Resolução CONAMA 307/02)',
    '170413-Níquel (Classe B conforme Resolução CONAMA 307/02)',    
    '170502(*)-Solos e rochas contendo contaminados combifenilas policloradas (PCB) (Classe D conforme Resolução CONAMA 307/02)',
    '170503(*)-Solos e rochas contendo outras substâncias perigosas (Classe D conforme Resolução CONAMA 307/02)',
    '170504-Solos e rochas não abrangidos em 17 05 03 (*) (Classe A conforme Resolução CONAMA 307/02)',
    '170505(*)-Lodos de dragagem contendo substâncias perigosas (Classe D conforme Resolução CONAMA 307/02)',
    '170506-Lodos de dragagem não abrangidos em 17 05 05 (*) (Classe C conforme Resolução CONAMA 307/02)',
    '170507(*)-Britas de linhas ferroviárias contendo substâncias perigosas (Classe D conforme Resolução CONAMA 307/02)',
    '170508-Britas de linhas de ferroviárias não abrangidas em 17 05 07 (*) (Classe A conforme Resolução CONAMA 307/02)',
    '170509(*)-Resíduos resultantes da incineração ou tratamento de solos contaminados por substâncias orgânicas perigosas (Classe D conforme Resolução CONAMA 307/02)',    
    '170601(*)-Materiais de isolamento contendo amianto  (Classe D conforme Resolução CONAMA 307/02)',
    '170603(*)-Outros materiais de isolamento contendo ou constituídos por substâncias perigosas (Classe D conforme Resolução CONAMA 307/02)',
    '170604-Materiais de isolamento não abrangidos em 17 06 01 (*) e 17 06 03 (*) (Classe A conforme Resolução CONAMA 307/02)',
    '170605(*)-Materiais de construção contendo amianto (por exemplo, telhas, tubos, etc.) (Classe D conforme Resolução CONAMA 307/02)',   
    '170801(*)-Materiais de construção à base de gesso contaminados com substâncias perigosas (Classe D conforme Resolução CONAMA 307/02)',
    '170802-Materiais de construção à base de gesso não abrangidos em 17 08 01 (*) (Classe B conforme Resolução CONAMA 307/02)',    
    '170902(*)-Resíduos de construção e demolição contendo PCB (por exemplo vedantes com PCB, revestimentos de piso à base de resinas com PCB, condensadores de uso doméstico com PCB) (Classe D conforme Resolução CONAMA 307/02)',
    '170903(*)-Outros resíduos de construção e demolição (incluindo misturas de resíduos) contendo substâncias perigosas (Classe D conforme Resolução CONAMA 307/02)',
    '170904-Mistura de resíduos de construção e demolição não abrangidos em 17 09 01 (*), 17 09 02 (*) e 17 09 03 (*) (Classe A conforme Resolução CONAMA 307/02)',
)

# Resíduos Sólidos de Saúde (RSS)
rss = (
    'Grupo A-Resíduos de Serviços de Saúde classificados como Grupos A1, A2, A3, A4 ou A5, conforme ANVISA RDC 222/2018 - Contempla os resíduos códigos 180101(*), 180102(*), 180103(*), 180104(*), 180105(*), 180106(*), 180107(*), 180108(*), 180109(*), 180110(*), 180111(*), 180112(*),180113(*), 180114(*) e 180115(*), conforme IBAMA 13/2012 .',
    '180203(*)-Efluentes de processadores de imagem (reveladores e fixadores) (Grupo B - ANVISA 222/18)',
    '180204(*)-Efluentes dos equipamentos automatizados utilizados em análises clínicas (Grupo B - ANVISA 222/18)',
    '180205(*)-Outros produtos considerados perigosos (Grupo B - ANVISA 222/18)',  
    '180301(*)-Materiais resultantes de laboratórios de pesquisa e ensino na área de saúde, laboratórios de análises clínicas e serviços de medicina nuclear e radioterapia que contenha radionuclídeos em quantidade superior aos limites de eliminação (CNEN-6.05)  (Grupo C - ANVISA 222/18)',
    '180401(*)-Materiais perfurocortantes ou escarificantes, tais como: lâminas de barbear, agulhas, escalpes, ampolas de vidro, brocas, limas endodônticas, pontas diamantadas, lâminas de bisturi, lancetas, tubos capilares; micropipetas; lâminas e lamínulas; espátulas; e todos os utensílios de vidro quebrados no laboratório (pipetas, tubos de coleta sanguínea e placas de Petri) e outras similares (Grupo E - ANVISA 222/18)',
)

# Resíduos Sólidos de Saneamento Básico (RSB)
rsb = (
    '190102-Materiais ferrosos removidos das cinzas',
    '190106(*)-Resíduos líquidos aquosos provenientes do tratamento de gases e outros resíduos líquidos aquosos',
    '190110(*)-Carvão ativado usado proveniente do tratamento de gases de combustão',
    '190111(*)-Cinzas e escórias contendo substâncias perigosas',
    '190112-Cinzas e escórias não abrangidas em 19 01 11 (*)',
    '190113(*)-Cinzas voláteis contendo substâncias perigosas',
    '190114-Cinzas voláteis não abrangidas em 19 01 13 (*)',
    '190115(*)-Cinzas de caldeiras contendo substâncias perigosas',
    '190116-Cinzas de caldeiras não abrangidas em 19 01 15 (*)',
    '190117(*)-Resíduos de pirólise contendo substâncias perigosas',
    '190119-Areias de leitos fluidizados',
    '190199-Outros resíduos não anteriormente especificados',   
    '190203-Misturas de resíduos contendo apenas resíduos não perigosos',
    '190204(*)-Misturas de resíduos contendo, pelo menos, um resíduos perigoso',
    '190205(*)-Lodos de tratamento físico-químico contendo substâncias perigosas',
    '190206-Lodos de tratamento físico-químico não abrangidos em 19 02 05 (*)',
    '190207(*)-Óleos e concentrados da separação',
    '190208(*)-Resíduos combustíveis líquidos contendo substâncias perigosas',
    '190209(*)-Resíduos combustíveis sólidos contendo substâncias perigosas',
    '190211(*)-Outros resíduos contendo substancias perigosas',
    '190299-Outros resíduos não anteriormente especificados',    
    '190304(*)-Resíduos assinalados como perigosos, parcialmente estabilizados',
    '190305-Resíduos estabilizados não abrangidos em 19 03 04 (*)',
    '190306(*)-Resíduos assinalados como perigosos, solidificados',
    '190307-Resíduos solidificados não abrangidos em 19 03 06 (*)',    
    '190401-Resíduos vitrificados',
    '190402(*)-Cinzas voláteis e outros resíduos do tratamento de gases de combustão',    
    '190501-Fração não compostada de resíduos urbanos e equiparados',
    '190502-Fração não compostada de resíduos animais e vegetais',
    '190503-Composto fora de especificação',
    '190599-Outros resíduos não anteriormente especificados',    
    '190603-Lodo do tratamento anaeróbico de resíduos urbanos e equiparados',
    '190604-Lamas e lodos de digestores de tratamento anaeróbico de resíduos urbanos e equiparados',
    '190605-Lodo de tratamento anaeróbico de resíduos animais e vegetais',
    '190606-Lama e lodos de digestores de tratamento anaeróbico de resíduos animais e vegetais',
    '190699-Outros resíduos não anteriormente especificados',    
    '190702(*)-Lixiviados ou líquidos percolados de aterros contendo substancias perigosas',
    '190703-Lixiviados ou líquidos percolados de aterros não abrangidos em 19 07 02 (*)',   
    '190801-Resíduos retirados da fase de gradeamento',
    '190802-Resíduos de desarenamento',
    '190805-Lodos de tratamento de efluentes urbanos',
    '190806(*)-Resinas de troca iônica, saturadas ou usadas',
    '190809-Misturas de gorduras e óleos, da separação água/óleo, contendo apenas óleos e gorduras alimentares',
    '190810(*)-Misturas de gorduras e óleos, da separação água/óleo, não abrangidas em 19 08 09',
    '190811(*)-Lodos de tratamento biológico de efluentes industriais contendo substancias perigosas',
    '190812-Lodos de tratamento biológico de efluentes industriais não abrangidos em 19 08 11 (*)',
    '190813(*)-Lodos de outros tratamentos de efluentes industriais contendo substancias perigosas',
    '190814-Lodos de outros tratamentos de efluentes industriais não abrangidos em 19 08 13 (*)',
    '190899-Outros resíduos não anteriormente especificados',    
    '190901-Resíduos retirados da fase de gradeamento',
    '190902-Lodos de clarificação da água',
    '190903-Lodos de descarbonatação',
    '190904-Carvão ativado usado',
    '190905-Resinas de troca iônica, saturadas ou usadas',
    '190999-Outros resíduos não anteriormente especificados',    
    '191001-Resíduos de ferro ou aço',
    '191002-Resíduos não ferrosos',
    '191003(*)-Frações leves e poeiras contendo substancias perigosas',
    '191004-Frações leves e poeiras não abrangidas em 19 10 03 (*)',
    '191005(*)-Outras frações contendo substancias perigosas',
    '191006-Outras frações não abrangidas em 19 10 05 (*)',    
    '191101(*)-Argilas de filtração usadas',
    '191102(*)-Borras ácidas',
    '191103(*)-Resíduos líquidos aquosos',
    '191105(*)-Lodos do tratamento local de efluentes contendo substancias perigosas',
    '191106-Lodos de tratamento local de efluentes não abrangidos em 19 11 05 (*)',
    '191199-Outros resíduos não anteriormente especificados',    
    '191301(*)-Resíduos da descontaminação de solos contendo substancias perigosas',
    '191302-Resíduos da descontaminação de solos não abrangidos em 19 13 01 (*)',
    '191303(*)-Lodos da descontaminação de solos contendo substancias perigosas',
    '191304-Lodos da descontaminação de solos não abrangidos em 19 13 03 (*)',
    '191305(*)-Lodos da descontaminação de águas freáticas contendo substancias perigosas',
    '191306-Lodos da descontaminação de águas freáticas não abrangidas em 19 13 05 (*)',
    '191307(*)-Resíduos líquidos aquosos e concentrados aquosos da descontaminação de águas freáticas contendo substancias perigosas',
    '191308-Resíduos líquidos aquosos e concentrados aquosos da descontaminação de águas freáticas não abrangidas em 19 13 07 (*)',
    '200304-Lodos de fossas sépticas',
)

# Resíduos Sólidos Industriais (RSI)
rsi = (
    '020201-Lodos provenientes da lavagem e limpeza',
    '020202-Resíduos de tecidos animais e orgânico de processo (sebo, soro, ossos, sangue, etc.)',
    '020203-Materiais impróprios para consumo ou processamento',
    '020204-Lodos do Tratamento local de efluentes',
    '020299-Outros resíduos não anteriormente especificados',
    '020301-Lodos de lavagem, limpeza, descasque, centrifugação e separação',
    '020302-Resíduos de agentes conservantes',
    '020303-Resíduos da extração por solventes',
    '020304-Materiais impróprios para consumo ou processamento',
    '020305-Lodos do Tratamento local de efluentes',
    '020399-Outros resíduos não anteriormente especificados',
    '020403-Lodos do Tratamento local de efluentes',
    '020404-Vinhaça',
    '020499-Outros resíduos não anteriormente especificados',
    '020501-Materiais impróprios para consumo ou processamento',
    '020502-Lodos do Tratamento local de efluentes',
    '020599-Outros resíduos não anteriormente especificados',
    '020601-Materiais impróprios para consumo ou processamento',
    '020602-Resíduos de agentes conservantes',
    '020603-Lodos do Tratamento local de efluentes',
    '020699-Outros resíduos não anteriormente especificados',
    '020701-Resíduos de lavagem, limpeza e redução mecânica das matérias primas',
    '020702-Resíduos da destilação de álcool',
    '020703-Resíduos de tratamentos químicos',
    '020704-Materiais impróprios para consumo ou processamento',
    '020705-Lodos do Tratamento local de efluentes',
    '020799-Outros resíduos não anteriormente especificados',
    '030101-Resíduos do descasque da madeira',
    '030104(*)-Serragem, aparas, fitas de aplainamento, madeira, aglomerados e folheados, contendo substancias perigosas',
    '030105-Serragem, aparas, fitas de aplainamento, madeira, aglomerados e folheados não abrangidos em 03 01 04 (*)',
    '030199-Outros resíduos não anteriormente especificados',
    '030201(*)-Produtos orgânicos não halogenados de preservação da madeira',
    '030202(*)-Agentes organoclorados de preservação da madeira',
    '030204(*)-Agentes inorgânicos de preservação da madeira',
    '030205(*)-Outros agentes de preservação da madeira contendo substancias perigosas',
    '030206(*)-Efluentes líquidos e resíduos originados no processo de preservação da madeira, provenientes de plantas que utilizam formulações que contem creosoto, com exceção dos efluentes líquidos dos processos de preservação da madeira que usam creosoto e/ou pentaclorofenol',
    '030207(*)-Efluentes líquidos e resíduos originados no processo de preservação da madeira, provenientes de plantas que utilizam ou tenham utilizado formulações clorofenólicas, com exceção dos efluentes líquidos dos processos de preservação da madeira que usam creosoto e/ou pentaclorofenol',
    '030208(*)-Efluentes líquidos e resíduos originados no processo de preservação da madeira, provenientes de plantas que utilizam conservantes inorgânicos contendo arsênio ou cromo, com exceção dos efluentes líquidos dos processos de preservação de madeira que usam creosoto e/ou pentaclorofenol',
    '030299-Agentes de preservação da madeira não anteriormente especificados',
    '030301-Resíduos do descasque da madeira e resíduos de madeira',
    '030302-Lodos de lixívia verde (provenientes da valorização da lixívia de cozimento ou licor negro)',
    '030305-Lodos de branqueamento, provenientes da reciclagem de papel',
    '030307-Rejeitos mecanicamente separados da fabricação de pasta a partir de papel e papelão usado',
    '030308-Resíduos de triagem de papel e papelão destinado a reciclagem',
    '030309-Resíduos de lodo de cal',
    '030310-Rejeitos de fibras e lodos de fibras, fillers, e revestimentos, provenientes da separação mecânica',
    '030311-Lodos do tratamento local de efluentes não abrangidos em 03 03 10',
    '030399-Outros resíduos não anteriormente especificados',
    '040101-Resíduos das operações de descarna e divisão de tripa.',
    '040102-Resíduos da operação de calagem',
    '040103(*)-Resíduos de desengorduramento contendo solventes sem fase aquosa',
    '040105-Licores de curtimento sem cromo',
    '040106-Lodos, em especial do tratamento de efluentes, contendo cromo',
    '040107-Lodos, em especial do tratamento de efluentes, sem cromo',
    '040108-Aparas, serragem e pós de couro provenientes de couros curtidos ao cromo',
    '040109-Resíduos da confecção e acabamentos',
    '040110-Lodo do caleiro',
    '040111(*)-Lodos provenientes do tratamento de efluentes líquidos originados no processo de curtimento de couros ao cromo',
    '040199-Outros resíduos não anteriormente especificados',
    '040209-Resíduos de materiais têxteis (têxteis impregnados, elastômeros, plastômeros)',
    '040210-Matéria orgânica de produtos naturais (por exemplo gordura, cera)',
    '040214(*)-Resíduos dos acabamentos, contendo solventes orgânicos ou contaminados',
    '040215-Resíduos dos acabamentos não abrangidos em 04 02 14 (*)',
    '040216(*)-Corantes e pigmentos contendo substancias perigosas',
    '040217-Corantes e pigmentos não abrangidos em 04 02 16 (*)',
    '040219(*)-Lodos do tratamento local de efluentes contendo substancias perigosas',
    '040220-Lodos do tratamento local de efluente não abrangidos em 04 02 19 (*)',
    '040221-Resíduos de fibras têxteis não processadas',
    '040222-Resíduos de fibras têxteis processadas',
    '040299-Outros resíduos não anteriormente especificados',
    '050102(*)-Lodos de dessalinização',
    '050103(*)-Resíduos provenientes de fundos de tanques empregados na indústria de refino de petróleo, inclusive do tanque de armazenamento de óleo crú',
    '050105(*)-Derrames de hidrocarbonetos',
    '050106(*)-Lodos contendo hidrocarbonetos provenientes de operações de manutenção das instalações ou equipamentos, inclusive lodos provenientes de separadores e da limpeza dos tubos dos trocadores de calor',
    '050108(*)-Outros alcatrões',
    '050109(*)-Lodos do tratamento local de efluentes contendo substancias perigosas',
    '050110-Lodos do tratamento local de efluentes não abrangidos em 05 01 09 (*)',
    '050111(*)-Resíduos de limpeza de combustíveis com bases',
    '050113-Lodos de tratamento de água para abastecimento de caldeiras',
    '050115(*)-Argilas de filtração usadas',
    '050117-Betumes',
    '050118(*)-Sólidos provenientes da emulsão residual oleosa, inclusive o sobrenadante proveniente de separadores tipo DAF (Dissolved Air Flotation)',
    '050199-Outros resíduos não anteriormente especificados',
    '050601(*)-Alcatrões ácidos',
    '050606(*)-Resíduos provenientes da recuperação e destilação de subprodutos do coque produzidos a partir do carvão',
    '050607(*)-Resíduos provenientes dos sistemas de tratamento de gases dos processos de coqueificação da carvão e da obtenção de subprodutos de coque produzidos a partir  do carvão',
    '050699-Outros resíduos não anteriormente especificados',
    '050701(*)-Resíduos contendo mercúrio',
    '050702-Resíduos contendo enxofre de dessulfurização de petróleo',
    '050799-Outros resíduos não anteriormente especificados',
    '060101(*)-Ácido sulfúrico e ácido sulfuroso',
    '060102(*)-Acido clorídrico',
    '060103(*)-Acido fluorídrico',
    '060104(*)-Acido fosfórico e acido fosforoso',
    '060105(*)-Acido nítrico e acido nitroso',
    '060106(*)-Outros ácidos',
    '060199-Outros resíduos não anteriormente especificados',
    '060201(*)-Hidróxido de cálcio',
    '060203(*)-Hidróxido de amônio',
    '060204(*)-Hidróxidos de sódio e de potássio',
    '060205(*)-Outras bases',
    '060299-Outros resíduos não anteriormente especificados',
    '060311(*)-Sais no estado sólido e em soluções contendo cianetos',
    '060313(*)-Sais no estado sólido e em soluções contendo metais pesados',
    '060314(*)-Sais no estado sólido e não abrangidos em 06 03 11 (*) e 03 03 13 (*)',
    '060315(*)-Óxidos metálicos contendo metais pesados',
    '060316-Óxidos metálicos não abrangidos em 06 03 15 (*)',
    '060399-Outros resíduos não anteriormente especificados',
    '060404(*)-Resíduos contendo mercúrio',
    '060405(*)-Resíduos contendo outros metais pesados',
    '060499-Outros resíduos não anteriormente especificados',
    '060502(*)-Lodos de tratamento local de efluentes contendo substancias perigosas',
    '060503-Lodos de tratamento local de efluentes não abrangidos em 06 05 02 (*)',
    '060602(*)-Resíduos contendo sulfuretos perigosos',
    '060603-Resíduos contendo sulfuretos não abrangidos em 06 06 02 (*)',
    '060699-Outros resíduos não anteriormente especificados',
    '060702(*)-Resíduos de carvão ativado utilizado na produção de cloro',
    '060703(*)-Lodos de sulfato de bário contendo mercúrio',
    '060704(*)-Soluções e ácidos, por exemplo, ácido de contato',
    '060705(*)-Lodos de purificação de salmoura e lodos provenientes do tratamento de efluentes líquidos originados no processo de produção de cloro em células de mercúrio',
    '060799-Outros resíduos não anteriormente especificados',
    '060903(*)-Resíduos cálcicos de reação contendo ou contaminados com substancias perigosas',
    '060904-Resíduos cálcicos de reação não abrangidos em 06 09 03 (*)',
    '060999-Outros resíduos não anteriormente especificados',
    '061002(*)-Resíduos contendo substancias perigosas',
    '061099-Outros resíduos não anteriormente especificados',
    '061102(*)-Lodos provenientes do tratamento  de efluentes líquidos originados no processo de produção do pigmento branco de dióxido de titânio, por meio do método de cloretos, a partir de minérios que contenham cromo',
    '061104(*)-Lodo de tratamento de efluentes líquidos originados na produção dos seguintes pigmentos: laranja e amarelo de cromo, laranja de molibdato, amarelo de zinco, verde de cromo, verde de óxido de cromo,(anidro e hidratado) e azul de ferro',
    '061199-Outros resíduos não anteriormente especificados',
    '061301(*)-Produtos inorgânicos de proteção das plantas, agentes de preservação da madeira e outros biocidas',
    '061302(*)-Carvão ativado usado - exceto 06 07 02 (*)',
    '061304(*)-Resíduos de processamento do amianto, incluindo pós e fibras',
    '061305(*)-Fuligem',
    '061399-Outros resíduos não anteriormente especificados',
    '070101(*)-Líquidos de lavagem e efluentes orgânicos aquosos',
    '070103(*)-Solventes, líquidos de lavagem e efluentes orgânicos halogenados',
    '070104(*)-Outros solventes, líquidos de lavagem e efluentes orgânicos',
    '070107(*)-Resíduos de destilação e resíduos de reação halogenados',
    '070108(*)-Outros resíduos de destilação e resíduos de reação',
    '070109(*)-Absorventes usados e tortas de filtro halogenados',
    '070110(*)-Outros absorventes usados e tortas de filtro',
    '070111(*)-Lodos de tratamento de efluentes contendo substancias perigosas',
    '070610(*)-Outros absorventes usados e tortas de filtro',
    '070611(*)-Lodos de tratamento de efluentes contendo substancias perigosas',
    '070612-Lodos do tratamento local de efluentes não abrangidas em 07 06 11 (*)',
    '070699-Outros resíduos não anteriormente especificados',
    '070701(*)-Líquidos de lavagem e efluentes orgânicos aquosos',
    '070703(*)-Solventes, líquidos de lavagem e efluentes orgânicos halogenados',
    '070704(*)-Outros solventes, líquidos de lavagem e efluentes orgânicos',
    '070708(*)-Outros resíduos de destilação e resíduos de reação',
    '070710(*)-Outros absorventes usados e tortas de filtro',
    '070711(*)-Lodos de tratamento de efluentes contendo substancias perigosas',
    '070712-Lodos do tratamento local de efluentes não abrangidas em 07 07 11 (*)',
    '070799-Outros resíduos não anteriormente especificados',
    '080111(*)-Resíduos de tintas e vernizes contendo solventes orgânicos ou outras substancias perigosas',
    '080112-Resíduos de tintas e vernizes não abrangidos em 08 01 11 (*)',
    '080113(*)-Lodos de tintas e vernizes contendo solventes orgânicos ou outras substancias perigosas',
    '080114-Lodos de tintas e vernizes não abrangias em 08 01 13 (*)',
    '080115(*)-Lodos aquosas contendo tintas e vernizes orgânicos ou outras substancias perigosas',
    '080116-Lodos aquosas contendo tintas e vernizes não abrangidas em 08 01 15 (*)',
    '080117(*)-Resíduos da remoção de tintas e vernizes contendo solventes orgânicos ou outras substancias perigosas',
    '080118-Resíduos da remoção de tintas e vernizes não abrangidos em 08 01 17 (*)',
    '080119(*)-Suspensões aquosas contendo tintas ou vernizes com solventes orgânicos ou outras substancias perigosas',
    '080120-Suspensões aquosas contendo tintas e vernizes não abrangidas em 08 01 19 (*)',
    '080121(*)-Resíduos de produtos de remoção de tintas e vernizes',
    '080122(*)-Lodos ou poeiras provenientes do sistema de controle de emissão de gases empregado na produção de tintas',
    '080199-Outros resíduos não anteriormente especificados',
    '080201-Resíduos de revestimentos na forma pulvurulenta',
    '080202-Lodos aquosas contendo materiais cerâmicos',
    '080203-Suspensões aquosas contendo materiais cerâmicos',
    '080204(*)-Resíduos de revestimentos contendo amianto',
    '080299-Outros resíduos não anteriormente especificados',
    '080307-Lodos aquosas contendo tintas de impressão',
    '080308-Resíduos líquidos aquosos contendo tintas de impressão',
    '080312(*)-Resíduos de tintas de impressão contendo substancias perigosas',
    '080313-Resíduos de tintas não abrangidos em 08  03 12 (*)',
    '080314(*)-Lodos de tintas contendo substancias perigosas',
    '080315-Lodos de tintas de impressão não abrangidas em 08 03 14 (*)',
    '080316-Resíduos de solução de água régia',
    '080317(*)-Resíduos de toner de impressão contendo substancias perigosas',
    '080318-Resíduos de toner de impressão não abrangidos em 08 03 17 (*)',
    '080319(*)-Óleos de dispersão',
    '080399-Outros resíduos não anteriormente especificados',
    '080409(*)-Resíduos de colas ou vedantes contendo solventes orgânicos ou outras substancias perigosas',
    '080410-Resíduos de colas ou vedantes não abrangidos em 08 04 09 (*)',
    '080411(*)-Lodos de colas ou vedantes contendo solventes orgânicos ou outras substancias perigosas',
    '100212-Resíduos do tratamento de agua de arrefecimento não abrangidos em 10 02 11 (*)',
    '100213(*)-Lodos e tortas de filtro de tratamento de gases contendo substancias perigosas',
    '100214-Lodos e tortas de filtro de tratamento de gases não abrangidos em 10 02 13 (*)',
    '100215-Outros lodos e tortas de filtro',
    '100216(*)-Poeiras provenientes do sistema de controle de emissão de gases empregado nos fornos Cubilot empregados na fundição de ferro',
    '100299-Outros resíduos não anteriormente especificados',
    '100302-Resíduos de ânodos',
    '100304(*)-Escórias da produção primária',
    '100306-Resíduos de alumina',
    '100308(*)-Escórias salinas da produção secundária',
    '100316-Escumas não abrangidas em 10 03 15 (*)',
    '100321(*)-Outras partículas e poeiras (incluindo poeiras da trituração de escórias) contendo substâncias perigosas',
    '100322-Outras partículas e poeiras (incluindo poeiras da trituração de escórias) não abrangidas em 10 03 21 (*)',
    '100325(*)-Lodos e tortas de filtro do tratamento de gases contendo substancias perigosas',
    '100326-Lodos e tortas de filtro do tratamento de gases não abrangidos em 10 03 25 (*)',
    '100329(*)-Resíduos do tratamento de escórias salinas e do tratamento das impurezas negras contendo substancias perigosas',
    '100330-Resíduos do tratamento de escórias salinas e do tratamento das impurezas negras não abrangidos em 10 03 29 (*)',
    '100399-Outros resíduos não anteriormente especificados',
    '100401(*)-Escórias da produção primária e secundária',
    '100402(*)-Impurezas e escumas da produção primária e secundária',
    '100404(*)-Lodos, lixivias ou poeiras provenientes de sistema de controle de emissão de gases empregado na produção primária e secundária do chumbo',
    '100405(*)-Outras partículas e poeiras',
    '100406(*)-Resíduos sólidos do tratamento de gases',
    '100407(*)-Lodos e tortas de filtro do tratamento de gases',
    '100499-Outros resíduos não anteriormente especificados',
    '100501-Escórias da produção primária e secundária',
    '100502(*)-Lodos calcários de anodos eletrolíticos originados na produção de zinco primário',
    '100508(*)-Resíduos do tratamento da água de arrefecimento contendo hidrocarbonetos',
    '100510(*)-Impurezas e escumas inflamáveis ou que, em contato com a água, libertam gases inflamáveis em quantidades perigosas',
    '100599-Outros resíduos não anteriormente especificados',
    '100601-Escórias da produção primária e secundária',
    '100604-Outras partículas e poeiras não perigosas',
    '100609(*)-Resíduos do tratamento da água de arrefecimento contendo hidrocarbonetos , incluindo lamas e lodos do adensamento da purga ácida do processo de produção de cobre primário',
    '100699-Outros resíduos não anteriormente especificados',
    '100707(*)-Resíduos do tratamento da água de arrefecimento contendo hidrocarbonetos',
    '100808(*)-Escórias salinas da produção primária e secundária',
    '100809-Outras escórias',
    '100810(*)-Impurezas e escumas inflamáveis ou que, em contato com a água, libertam gases inflamáveis em quantidades perigosas',
    '100812(*)-Resíduos da fabricação de anodos contendo alcatrão',
    '100814-Resíduos de anodos',
    '100819(*)-Resíduos do tratamento da água de arrefecimento contendo hidrocarbonetos',
    '100899-Outros resíduos não anteriormente especificados',
    '100903-Escórias do forno',
    '100905(*)-Moldes e modelos e moldes de fundição não vazados contendo substancias perigosas',
    '100906-Moldes e modelos e moldes de fundição não vazados não abrangidos em 10 09 05 (*)',
    '100907(*)-Moldes e modelos e moldes de fundição vazados contendo substancias perigosas',
    '100908-Moldes e modelos e moldes de fundição vazados não abrangidos em 10 09 07 (*)',
    '100909(*)-Poeiras de gases de combustão contendo substancias perigosas',
    '100910-Poeiras de gases de combustão não abrangidos em 10 09 09 (*)',
    '100911(*)-Outras partículas contendo substancias perigosas',
    '100912-Outras partículas não abrangidas em 10 09 11 (*)',
    '100913(*)-Resíduos de aglutinantes contendo substâncias perigosas',
    '100914-Resíduos de aglutinantes não abrangidos em 10 09 13 (*)',
    '100999-Outros resíduos não anteriormente especificados',
    '101003-Escórias do forno',
    '101005(*)-Moldes e modelos e moldes de fundição não vazados contendo substancias perigosas',
    '101006-Moldes e modelos e moldes de fundição não vazados não abrangidos em 10 10 05 (*)',
    '101007(*)-Moldes e modelos e moldes de fundição vazados contendo substancias perigosas',
    '101008-Moldes e modelos e moldes de fundição vazados não abrangidos em 10 10 07 (*)',
    '101009(*)-Poeiras de gases de combustão contendo substancias perigosas',
    '101010-Poeiras de gases de combustão não abrangidas em 10 10 09 (*)',
    '101011(*)-Outras partículas contendo substancias perigosas',
    '101013(*)-Resíduos de aglutinantes contendo substancias perigosas',
    '101099-Outros resíduos não anteriormente especificados',
    '101103-Resíduos de materiais fibrosos à base de vidro',
    '101105-Partículas e poeiras',
    '101109(*)-Resíduos da preparação da mistura (antes do processo térmico) contendo substancias perigosas',
    '101110-Resíduos da preparação da mistura (antes do processo térmico) não abrangidas em 10 11 09 (*)',
    '101111(*)-Resíduos de vidro em pequenas partículas e em pó de vidro contendo metais pesados (por exemplo, tubos catódicos)',
    '101112-Resíduos de vidros não abrangidos em 10 11 11 (*)',
    '101113(*)-Lodos de polimento e retificação de vidro contendo substancias perigosas',
    '101114-Lodos de polimento e retificação de vidro não abrangidos em 10 11 13 (*)',
    '101116-Resíduos sólidos de tratamento de gases de combustão não abrangidos em 10 11 15 (*)',
    '101118-Lodos e tortas de filtro do tratamento de gases de combustão não abrangidas em 10 11 17 (*)',
    '101119(*)-Resíduos sólidos do tratamento local de efluentes contendo substancias perigosas',
    '101120-Resíduos sólidos do tratamento local de efluentes não abrangidas em 10 11 19 (*)',
    '101199-Outros resíduos não anteriormente especificados',
    '101201-Resíduos da preparação da mistura (antes do tratamento térmico)',
    '101203-Partículas e poeiras',
    '101205-Lodos e tortas de filtro do tratamento de gases',
    '101206-Moldes fora de uso',
    '101208-Resíduos de fabricação de peças cerâmicas, tijolos, ladrilhos, telhas e produtos de construção (após o processo térmico)',
    '101210-Resíduos sólidos do tratamento de gases não abrangidos em 10 12 09 (*)',
    '101212-Resíduos de vitrificação não abrangidos em 10 12 11 (*)',
    '101213-Lodos de tratamento local de efluentes',
    '101299-Outros resíduos não anteriormente especificados',
    '101301-Resíduos de preparação da mistura antes do processo térmico',
    '101304-Resíduos da calcinação e hidratação da cal',
    '101306-Partículas e poeiras exceto 10 13 12  (*) e 10 13 13',
    '101307-Lodos e tortas de filtro do tratamento de gases',
    '101309(*)-Resíduos da fabricação de fibrocimento contendo amianto',
    '101310-Resíduos da fabricação de fibrocimento não abrangidos em 10 13 09 (*)',
    '101311-Resíduos de materiais compósitos à base de cimento não abrangidos em 10 13 09 (*) e 10 13 10',
    '101314-Resíduos de cimento e de lodos de cimento',
    '101399-Outros resíduos não anteriormente especificados',
    '101401(*)-Resíduos de limpeza de gases contendo mercúrio',
    '110104(*)-Banho de decapagem exaurido proveniente das operações de acabamento do aço',
    '110105(*)-Ácidos de decapagem',
    '110106(*)-Ácidos não anteriormente especificados',
    '110107(*)-Bases de decapagem',
    '110108(*)-Lodos de fosfatização',
    '110109(*)-Lodos e tortas de filtro contendo substancias perigosas',
    '110110-Lodos e tortas de filtro não abrangidas em 11 01 09 (*)',
    '110111(*)-Soluções exauridas, lodos e líquidos de lavagem aquosos contendo cianeto e/ou outras substancias perigosas',
    '110112-Líquidos de lavagem aquosos não abrangidos em 11 01 11 (*)',
    '110113(*)-Resíduos de desengorduramento contendo substancias perigosas',
    '110114-Resíduos de desengorduramento não abrangidas em 11 01 13 (*)',
    '110115(*)-Eluatos e lodos de sistema de membranas ou de permuta iônica contendo substancias perigosas',
    '110116(*)-Resinas de permuta iônica saturadas ou usadas',
    '110198(*)-Outros resíduos contendo substancias perigosas',
    '110199-Outros resíduos não anteriormente especificados',
    '110202(*)-Lodos da hidrometalurgia do zinco',
    '110206-Resíduos de processos hidrometalurgicos do cobre não abrangidos em 11 02 05 (*)',
    '110207(*)-Outros resíduos contendo substancias perigosas',
    '110299-Outros resíduos não anteriormente especificados',
    '110301(*)-Resíduos contendo cianetos',
    '110302(*)-Outros resíduos',
    '110303(*)-Lodos originados no tratamento de efluentes líquidos provenientes dos banhos de têmpera das operações de tratamento térmico de metais nos quais são utilizados cianetos',
    '110501-Escórias e cinzas de zinco não perigosas',
    '110502(*)-Cinzas de zinco contendo cádmio ou chumbo',
    '110503(*)-Resíduos sólidos do tratamento de gases',
    '110504(*)-Fluxantes usados',
    '110599-Outros resíduos não anteriormente especificados',
    '120101-Aparas e limalhas de metais ferrosos',
    '120102-Poeiras e partículas de metais ferrosos',
    '120103-Aparas e limalhas de metais não ferrosos',
    '120104-Poeiras e partículas de metais não ferrosos',
    '120105-Aparas de matérias plásticas',
    '120106(*)-Óleos minerais de corte e usinagem com halogênios (exceto emulsões, misturas e soluções)',
    '120107(*)-Óleos minerais de corte e usinagem sem halogênios (exceto emulsões, misturas e soluções)',
    '120108(*)-Emulsões, misturas e soluções de corte e usinagem com halogênios',
    '120109(*)-Emulsões, misturas e soluções de corte e usinagem sem halogênios',
    '120110(*)-Óleos sintéticos de corte e usinagem',
    '120112(*)-Ceras e gorduras usadas',
    '120113-Resíduos de soldadura',
    '120114(*)-Lodos da usinagem contendo substancias perigosas',
    '120115-Lodos de usinagem não abrangidas em 10 01 14 (*)',
    '120116(*)-Resíduos de materiais de polimento contendo substancias perigosas',
    '120117-Resíduos de materiais de polimento não abrangidos em 12 01 16 (*)',
    '120118(*)-Lodos metálicos (lodos de retificação, superacabamento e lixamento) contendo óleo',
    '120119(*)-Óleos de usinagem facilmente biodegradáveis',
    '120120(*)-Mós e materiais de retificação usados contendo substâncias perigosas',
    '120121-Mós e materiais de retificação usados não abrangidos em 12 01 20 (*)',
    '120199-Outros resíduos não anteriormente especificados',
    '120301(*)-Líquidos de lavagem aquosos',
    '130101(*)-Óleos hidraúlicos contendo PCB (1)',
    '130104(*)-Emulsões coloidais',
    '130105(*)-Emulsões não coloidais',
    '130109(*)-Óleos hidráulicos minerais clorados',
    '130110(*)-Óleos hidráulicos minerais não clorados',
    '130111(*)-Óleos hidráulicos sintéticos',
    '130112(*)-Óleos hidráulicos facilmente biodegradáveis',
    '130113(*)-Outros óleos hidráulicos',
    '130201(*)-Óleos de motores, transmissões e lubrificação usados ou contaminados',
    '130299(*)-Outros óleos de motores, transmissão e lubrificação',
    '130301(*)-Óleos de isolamento térmico, de refrigeração e de transmissão de calor usados, fluidos dielétricos e resíduos contaminados com bifenilas policloradas (PCB)',
    '130306(*)-Óleos minerais isolantes , de refrigeração e de transmissão de calor clorados, não abrangidos em 13 03 01 (*)',
    '130307(*)-Óleos minerais isolantes , de refrigeração e de transmissão de calor não clorados',
    '130308(*)-Óleos sintéticos isolantes, de refrigeração e de transmissão de calor',
    '130309(*)-Óleos facilmente biodegradáveis isolantes, de refrigeração e de transmissão de calor',
    '130310(*)-Outros óleos isolantes, de refrigeração e de transmissão de calor',
    '130501(*)-Resíduos sólidos provenientes de desarenadores e de separadores óleo/água',
    '130502(*)-Lodo proveniente dos separadores óleo/água',
    '130503(*)-Lodo proveniente do interceptor',
    '130506(*)-Óleos provenientes dos separadores óleo/água',
    '130507(*)-Água com óleo proveniente dos separadores óleo/água',
    '130508(*)-Misturas de resíduos provenientes de desarenadores e de separadores',
    '130701(*)-Fuelóleo e óleo diesel',
    '130702(*)-Gasolina',
    '130703(*)-Outros combustíveis (incluindo misturas)',
    '130801(*)-Lodos ou emulsões de dessalinização',
    '130802(*)-Outras emulsões e misturas',
    '130899(*)-Outros resíduos não anteriormente especificados',
    '140601(*)-Clorofluorcarbonetos (CFC), HCFC, HFC',
    '140602(*)-Outros solventes e misturas de solventes halogenados',
    '140603(*)-Outros solventes e misturas de solventes',
    '140604(*)-Lodos ou resíduos sólidos contendo solventes halogenados',
    '140605(*)-Lodos ou resíduos sólidos contendo outros solventes',
)

# Resíduos Sólidos de Transporte (RST)
rst = (
    '130401(*)-Óleos bunker de navios de navegação interior',
    '130403(*)-Óleos bunker de outros tipos de navios',
    '160103(*)-Veículos em fim de vida',
    '160104-Veículos em fim de vida esvaziados de líquidos e outros componentes perigosos',
    '160106(*)-Resíduo proveniente da trituração de veículos em fim de vida (Ash Schredder Residue)',
    '160107(*)-Filtros de óleo automotivos',
    '160108(*)-Componentes e peças contendo mercúrio',
    '160109(*)-Componentes e peças contendo PCB',
    '160110(*)-Componentes explosivos, por exemplo, almofadas de ar (air bags)',
    '160111(*)-Pastilhas de freio contendo amianto',
    '160112-Pastilhas de freio não abrangidas em 16 01 11 (*)',
    '160114(*)-Fluidos anticongelantes contendo substancias perigosas',
    '160116-Recipientes para gás liquefeito sob pressão',
    '160117-Sucatas metálicas ferrosas',
    '160118-Sucatas metálicas não ferrosas',
    '160119-Plástico',
    '160120-Vidro',
    '160121(*)-Componentes perigosos não abrangentes em 16 01 07 (*) a 16 01 11 (*), 16 01 13 (*) e 16 01 14 (*)',
    '160122-Componentes não anteriormente especificados',
    '160199-Outros resíduos não anteriormente especificados',
    '160708(*)-Resíduos contendo hidrocarbonetos',
    '160709(*)-Resíduos contendo outras substâncias perigosas',
    '160799-Outros resíduos não anteriormente especificados',
)

# Resíduos Sólidos de Mineração (RSM)
rsm = (
    '010101-Resíduos da Extração de Minérios Metálicos',
    '010102-Resíduos da Extração de Minérios Não Metálicos',
    '010304(*)-Rejeitados geradores de ácidos, resultantes da transformação de sulfuretos',
    '010305(*)-Outros rejeitados contendo substancias perigosas',
    '010306-Rejeitados não abrangidos em 01 03 04 (*) e 01 03 05 (*)',
    '010307(*)-Outros resíduos contendo substancias perigosas, resultantes da transformação física e química de minérios metálicos',
    '010308-Poeiras e pós não abrangidos em 01 03 07 (*)',
    '010309-Lamas vermelhas da produção de alumina não abrangidas em 01 03 07',
    '010399-Outros resíduos não anteriormente especificados',
    '010407(*)-Resíduos contendo substancia perigosas, resultantes da transformação física e química de minérios não metálicos',
    '010408-Cascalhos e fragmentos de rocha não abrangidos em 01 04 07 (*)',
    '010409-Areias e Argilas',
    '010410-Poeiras e pós não abrangidos em 01 04 07 (*)',
    '010412-Rejeitados e outros resíduos, resultantes da lavagem de minérios, não abrangidos em 01 04 07 (*)',
    '010413-Resíduos de corte e serragem de pedra não abrangidos em 01 04 07 (*)',
    '010499-Outros resíduos não anteriormente especificados',
    '010504-Lodos e outros resíduos de perfuração contendo água doce',
    '010505(*)-Lodos e outros resíduos de perfuração contendo hidrocarbonetos',
    '010506(*)-Lodos e outros resíduos de perfuração contendo substancias perigosas',
    '010507-Lodos e outros resíduos de perfuração contendo sais de bário não abrangidos em 01 05 05 (*) e 01 05 06 (*)',
    '010508-Lodos e outros resíduos de perfuração contendo cloretos não abrangidos em 01 05 05 (*) e 01 05 06 (*)',
    '010599-Outros resíduos não anteriormente especificados',
)

# Resíduos Sólidos Agrossilvipastoris (RSA)
rsa = (
    '020101-Lodos provenientes da lavagem e limpeza',
    '020102-Resíduos de tecidos animais',
    '020103-Resíduos de tecidos vegetais',
    '020104-Resíduos de plásticos (excluindo embalagens)',
    '020106-Fezes, urina e estrume de animais (incluindo palha suja), efluentes recolhidos separadamente e tratados noutro local',
    '020107-Resíduos Silvícolas',
    '020108(*)-Resíduos agrotóxicos e afins (agroquímicos) contendo substancias perigosas',
    '020109-Resíduos agrotóxicos e afins (agroquímicos) não abrangidos em 02 01 08 (*)',
    '020110-Resíduos metálicos, como por exemplo, estruturas metálicas, sucatas metálicas, varas e cabos utilizados em campo',
    '020199-Outros resíduos não anteriormente especificados',
)

# Outros (16) - Resíduos não especificados em outros capítulos desta Lista (exceto 160119, 160120, 160123 ao 160129, 1602, 1606)
outros = (  
    '160303(*)-Resíduos inorgânicos contendo substâncias perigosas',
    '160304-Resíduos inorgânicos não abrangidos em 16 03 03 (*)',
    '160305(*)-Resíduos orgânicos contendo substâncias perigosas',
    '160306-Resíduos orgânicos não abrangidos em 16 03 05 (*)',   
    '160405(*)-Carvão usado proveniente do tratamento de efluentes líquidos que contenham explosivos',    
    '160504(*)-Gases em recipientes sob pressão (incluindo freons e halons) contendo substâncias perigosas',
    '160505-Gases em recipientes sob pressão não abrangidos em 13 05 04 (*)',
    '160506(*)-Produtos químicos de laboratório contendo ou compostos por substâncias perigosas, incluindo misturas de produtos químicos de laboratório',
    '160507(*)-Produtos químicos inorgânicos de laboratório contendo ou compostos por substancias perigosas',
    '160508(*)-Produtos químicos orgânicos fora de uso contendo ou compostos por substâncias perigosas',
    '160509-Produtos químicos fora de uso não abrangidos em 16 05 06 (*), 16 05 07 (*) ou 16 05 08 (*)',              
    '160802(*)-Catalisadores usados contendo metais de transição (4) ou compostos de metais de transição perigosos',
    '160805(*)-Catalizadores usados contendo ácido fosfórico',
    '160806(*)-Líquidos usados utilizados como catalisadores',
    '160807(*)-Catalisadores usados provenientes do reator de hidrocloração utilizado na produção de 1,1,1-tricloroetano',
    '160899(*)-Outros catalizadores usados contaminados com substâncias perigosas',   
    '160901(*)-Permanganatos, por exemplo, permanganato de potássio',
    '160902(*)-Cromatos, por exemplo, cromato de potássio, dicromato de potássio ou de sódio',
    '160903(*)-Peróxidos , por exemplo, água oxigenada',
    '160904(*)-Substâncias oxidantes não anteriormente especificados',    
    '161001(*)-Resíduos líquidos aquosos contendo substâncias perigosas',
    '161002-Resíduos líquidos aquosos não abrangidos em 16 10 01 (*)',
    '161003(*)-Concentrados aquosos contendo substâncias perigosas',
    '161004-Concentrados aquosos não abrangidos em 16 10 03 (*)',    
    '161101(*)-Revestimentos de fornos e refratários à base de carbono provenientes de processos metalúrgicos contendo substâncias perigosas',
    '161102-Revestimentos de fornos e refratários à base de carbono não abrangidos em 16 11 01 (*)',
    '161103(*)-Outros revestimentos de fornos e refratários provenientes de processos metalúrgicos contendo substâncias perigosas',
    '161104-Outros revestimentos de fornos e refratários não abrangidos em 16 11 03 (*)',
    '161105(*)-Revestimentos de fornos e refratários provenientes de processos não metalúrgicos contendo substâncias perigosas',
    '161106-Revestimentos de fornos e refratários provenientes de processos não metalúrgicos não abrangidos em 16 11 05 (*)',
)

# %%
""" 
RESÍDUOS DE MINERAÇÃO (RSM) - MTR & SIGMINE
Base de dados: MTR & SIGMINE

Seleciona todos os dados das tabelas MTR & SIGMINE cujos geradores dos MTRs sejam as empresas da base de dados SIGMINE e 
cujo município do gerador do MTR seja o município da empresa do SIGMINE

todo: quando a nova base de dados do IMA estiver disponível, verificar se há um detalhamento do tipo de resíduo e verificar
todo: se há como relacionar o tipo de resíduo com a atividade de mineração da substância mineral em questão

todo: fazer a geração das planilhas auxiliares, por municipio. Verificar em quais abas da planilha pers os dados serão inseridos.
"""

import pandas as pd

mineracao = pd.read_sql_query("SELECT * FROM mtr JOIN mineracao_sigmine ON mtr.nome_gerador = mineracao_sigmine.NOME AND mtr.municipio_gerador = mineracao_sigmine.NM_MUNICIP;","sqlite:///base_de_dados.db")
mineracao.to_excel("1-mtr_primeira_aba_planilha_pers/#mtr_sigmine.xlsx")

# %%
""" 
RESÍDUOS DE MINERAÇÃO (RSM) NO ESTADO DE SC 
Base de dados: MTR

Gera um compilado dos dados dos MTRs no Estado
"""
import pandas as pd
import locale
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')

anos = "2024","2023","2022","2021","2020","2019","2018","2017","2016"

df_rsm = pd.DataFrame()    
df_rsm.index = [
    "Número de MTR's de RSM com origem no Estado:",
    "Número de MTR's de RSM com destino no Estado:",
    "Quantidade de RSM (ton) registrados em MTR's com origem no Estado:",
    "Quantidade de RSM (ton) registrados em MTR's com destino no Estado:"
]

for ano in anos:
    municipio_gerador_rsm = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador != "OUTRO ESTADO" AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsm])
    municipio_destinador_rsm = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador != "OUTRO ESTADO" AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsm])
    df_rsm[ano] = [municipio_gerador_rsm['codigo_manifesto'].count(), 
                   municipio_destinador_rsm['codigo_manifesto'].count(), 
                   locale.format_string('%.2f', municipio_gerador_rsm['quantidade_item_manifesto'].sum(), grouping=True),
                   locale.format_string('%.2f', municipio_destinador_rsm['quantidade_item_manifesto'].sum(), grouping=True)
                  ]
    df_rsm.to_excel("1-mtr_primeira_aba_planilha_pers/#RSM_Santa_Caratina.xlsx")

# %%
""" 
Aba: 1.Informações Gerais
Base de dados: MTR
"""
import pandas as pd
import locale
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')

# Todos os Municípios do Estado
#municipios = "ABDON BATISTA", "ABELARDO LUZ", "AGROLÂNDIA", "AGRONÔMICA", "ÁGUA DOCE", "ÁGUAS DE CHAPECÓ", "ÁGUAS FRIAS", "ÁGUAS MORNAS", "ALFREDO WAGNER", "ALTO BELA VISTA", "ANCHIETA", "ANGELINA", "ANITA GARIBALDI", "ANITÁPOLIS", "ANTÔNIO CARLOS", "APIÚNA", "ARABUTÃ", "ARAQUARI", "ARARANGUÁ", "ARMAZÉM", "ARROIO TRINTA", "ASCURRA", "ATALANTA", "AURORA", "BALNEÁRIO ARROIO DO SILVA", "BALNEÁRIO BARRA DO SUL", "BALNEÁRIO CAMBORIÚ", "BALNEÁRIO GAIVOTA", "BALNEÁRIO PIÇARRAS", "BALNEÁRIO RINCÃ
O SUL","BALNEÁRIO RINCÃO","LAURO MÜLLER","SIDERÓPOLIS","NOVA VENEZA","TREVISO ","TUBARÃO","IMBITUBA","LAGUNA","BRAÇO DO NORTE","CAPIVARI DE BAIXO","JAGUARUNA","SÃO LUDGERO","SANGÃO","IMARUÍ","PESCARIA BRAVA","ARMAZÉM","TREZE DE MAIO","GRÃO-PARÁ","RIO FORTUNA","PEDRAS GRANDES","SÃO MARTINHO","SANTA ROSA DE LIMA","GAROPABA","PAULO LOPES","GRAVATAL"

for municipio in municipios:
    anos = "2024","2023","2022","2021","2020","2019","2018","2017","2016"

    # Dataframes
    df_embranco = pd.DataFrame(["-"])
    
    df_rsu = pd.DataFrame()
    df_rsu.index = [
        "Número de MTR's de RSU com origem no município:",
        "Número de MTR's de RSU com destino no município:",
        "Quantidade de RSU (ton) registrados em MTR's com origem no município:",
        "Quantidade de RSU (ton) registrados em MTR's com destino no município:"
    ]
    df_rsv = pd.DataFrame()    
    df_rsv.index = [
        "Número de MTR's de RSV com origem no município:",
        "Número de MTR's de RSV com destino no município:",
        "Quantidade de RSV (ton) registrados em MTR's com origem no município:",
        "Quantidade de RSV (ton) registrados em MTR's com destino no município:"
    ]
    df_rcc = pd.DataFrame()    
    df_rcc.index = [
        "Número de MTR's de RCC com origem no município:",
        "Número de MTR's de RCC com destino no município:",
        "Quantidade de RCC (ton) registrados em MTR's com origem no município:",
        "Quantidade de RCC (ton) registrados em MTR's com destino no município:"
    ]
    df_rss = pd.DataFrame()    
    df_rss.index = [
        "Número de MTR's de RSS com origem no município:",
        "Número de MTR's de RSS com destino no município:",
        "Quantidade de RSS (ton) registrados em MTR's com origem no município:",
        "Quantidade de RSS (ton) registrados em MTR's com destino no município:"
    ]
    df_rsb = pd.DataFrame()    
    df_rsb.index = [
        "Número de MTR's de RSAE com origem no município:",
        "Número de MTR's de RSAE com destino no município:",
        "Quantidade de RSAE (ton) registrados em MTR's com origem no município:",
        "Quantidade de RSAE (ton) registrados em MTR's com destino no município:"
    ]
    df_rsi = pd.DataFrame()    
    df_rsi.index = [
        "Número de MTR's de RSI com origem no município:",
        "Número de MTR's de RSI com destino no município:",
        "Quantidade de RSI (ton) registrados em MTR's com origem no município:",
        "Quantidade de RSI (ton) registrados em MTR's com destino no município:"
    ]
    df_rst = pd.DataFrame()    
    df_rst.index = [
        "Número de MTR's de RST com origem no município:",
        "Número de MTR's de RST com destino no município:",
        "Quantidade de RST (ton) registrados em MTR's com origem no município:",
        "Quantidade de RST (ton) registrados em MTR's com destino no município:"
    ]
    df_rsm = pd.DataFrame()    
    df_rsm.index = [
        "Número de MTR's de RSM com origem no município:",
        "Número de MTR's de RSM com destino no município:",
        "Quantidade de RSM (ton) registrados em MTR's com origem no município:",
        "Quantidade de RSM (ton) registrados em MTR's com destino no município:"
    ]
    df_rsa = pd.DataFrame()    
    df_rsa.index = [
        "Número de MTR's de RSA com origem no município:",
        "Número de MTR's de RSA com destino no município:",
        "Quantidade de RSA (ton) registrados em MTR's com origem no município:",
        "Quantidade de RSA (ton) registrados em MTR's com destino no município:"
    ]
    df_outros = pd.DataFrame()    
    df_outros.index = [
        "Número de MTR's de outros tipos de resíduos com origem no município:",
        "Número de MTR's de outros tipos de resíduos com destino no município:",
        "Quantidade de outros tipos de resíduos (ton) registrados em MTR's com origem no município:",
        "Quantidade de outros tipos de resíduos (ton) registrados em MTR's com destino no município:"
    ]

    # Extração dos dados
    for ano in anos:
        municipio_gerador_rsu = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsu])
        municipio_destinador_rsu = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsu])        
        df_rsu[ano] = [municipio_gerador_rsu['codigo_manifesto'].count(), municipio_destinador_rsu['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rsu['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsu['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_rsv = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsv])
        municipio_destinador_rsv = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsv])
        df_rsv[ano] = [municipio_gerador_rsv['codigo_manifesto'].count(), municipio_destinador_rsv['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rsv['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsv['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_rcc = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rcc])
        municipio_destinador_rcc = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rcc])
        df_rcc[ano] = [municipio_gerador_rcc['codigo_manifesto'].count(), municipio_destinador_rcc['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rcc['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rcc['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_rss = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rss])
        municipio_destinador_rss = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rss])
        df_rss[ano] = [municipio_gerador_rss['codigo_manifesto'].count(), municipio_destinador_rss['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rss['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rss['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_rsb = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsb])
        municipio_destinador_rsb = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsb])
        df_rsb[ano] = [municipio_gerador_rsb['codigo_manifesto'].count(), municipio_destinador_rsb['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rsb['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsb['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_rsi = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsi])
        municipio_destinador_rsi = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsi])
        df_rsi[ano] = [municipio_gerador_rsi['codigo_manifesto'].count(), municipio_destinador_rsi['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rsi['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsi['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_rst = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rst])
        municipio_destinador_rst = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rst])
        df_rst[ano] = [municipio_gerador_rst['codigo_manifesto'].count(), municipio_destinador_rst['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rst['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rst['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_rsm = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsm])
        municipio_destinador_rsm = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsm])
        df_rsm[ano] = [municipio_gerador_rsm['codigo_manifesto'].count(), municipio_destinador_rsm['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rsm['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsm['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_rsa = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsa])
        municipio_destinador_rsa = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsa])
        df_rsa[ano] = [municipio_gerador_rsa['codigo_manifesto'].count(), municipio_destinador_rsa['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_rsa['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsa['quantidade_item_manifesto'].sum(), grouping=True)]
        
        municipio_gerador_outros = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_gerador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[outros])
        municipio_destinador_outros = pd.read_sql_query("""SELECT * FROM mtr WHERE strftime('%Y', data_recebimento_manifesto) = '"""+ano+"""' AND municipio_destinador='"""+municipio+"""' AND tipo_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[outros])
        df_outros[ano] = [municipio_gerador_outros['codigo_manifesto'].count(), municipio_destinador_outros['codigo_manifesto'].count(), locale.format_string('%.2f', municipio_gerador_outros['quantidade_item_manifesto'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_outros['quantidade_item_manifesto'].sum(), grouping=True)]
        
    df_concat = pd.concat([df_rsu, df_embranco, df_rsv, df_embranco, df_rcc, df_embranco, df_rss, df_embranco, df_rsb, df_embranco, df_rsi, df_embranco, df_rst, df_embranco, df_rsm, df_embranco, df_rsa, df_embranco, df_outros])
    df_concat.to_excel("1-mtr_primeira_aba_planilha_pers/"+municipio+'.xlsx')

# %%
""" 
Aba: 1.Informações Gerais
Base de dados: DMR

Lógica da consulta:

Para as DMRs GERADOS em determinado município (campo declaracao_item_municipio)
- O campo declaracao_item_pessoa_tipo precisa conter um ou mais dos seguintes itens: 'Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador'
- O campo declaracao_pessoa_tipo precisa conter um ou mais dos seguintes itens: 'Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador'

Para as DMRs DESTINADOS em determinado município (campo declaracao_item_municipio)
- O campo declaracao_item_pessoa_tipo precisa conter um ou mais dos seguintes itens: 'Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador'
- O campo declaracao_pessoa_tipo precisa conter um ou mais dos seguintes itens: 'Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador'

Considera-se exceção (programação) / erro de sessão de dados(*) situações onde ocorram de os campos declaracao_item_pessoa_tipo e declaracao_pessoa_tipo terem dados iguais, ex.: ambos serem geradores ou ambos serem destinadores. 
Por este motivo, não se criou uma lógica de consulta para este tipo de situação, sendo estes dados descartados.

(*) Quando há falhas na coleta, armazenamento, processamento ou análise de dados. No caso das DMRs, pode ser erro no preenchimento do documento, por motivos diversos, por exemplo: falta de conhecimento de quem preenche

"""
import pandas as pd
import locale
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')

# Todos os Municípios do Estado
#municipios = "ABDON BATISTA", "ABELARDO LUZ", "AGROLÂNDIA", "AGRONÔMICA", "ÁGUA DOCE", "ÁGUAS DE CHAPECÓ", "ÁGUAS FRIAS", "ÁGUAS MORNAS", "ALFREDO WAGNER", "ALTO BELA VISTA", "ANCHIETA", "ANGELINA", "ANITA GARIBALDI", "ANITÁPOLIS", "ANTÔNIO CARLOS", "APIÚNA", "ARABUTÃ", "ARAQUARI", "ARARANGUÁ", "ARMAZÉM", "ARROIO TRINTA", "ASCURRA", "ATALANTA", "AURORA", "BALNEÁRIO ARROIO DO SILVA", "BALNEÁRIO BARRA DO SUL", "BALNEÁRIO CAMBORIÚ", "BALNEÁRIO GAIVOTA", "BALNEÁRIO PIÇARRAS", "BALNEÁRIO RINCÃO", "BANDEIRANTE", "BARRA BONITA", "BARRA VELHA", "BELA VISTA DO TOLDO", "BELMONTE", "BENEDITO NOVO", "BIGUAÇU", "BLUMENAU", "BOCAINA DO SUL", "BOM JARDIM DA SERRA", "BOM JESUS", "BOM JESUS DO OESTE", "BOM RETIRO", "BOMBINHAS", "BOTUVERÁ", "BRAÇO DO NORTE", "BRAÇO DO TROMBUDO", "BRUNÓPOLIS", "BRUSQUE", "CAÇADOR", "CAIBI", "CALMON", "CAMBORIÚ", "CAPÃO ALTO", "CAPIXABA", "CAPIVARI DE BAIXO", "CATANDUVAS", "CAXAMBU DO SUL", "CEDRO
    df_embranco = pd.DataFrame(["-"])
    
    df_rsu = pd.DataFrame()
    df_rsu.index = [
        "Número de DMR's de RSU com origem no município:",
        "Número de DMR's de RSU com destino no município:",
        "Quantidade de RSU (ton) registrados em DMR's com origem no município:",
        "Quantidade de RSU (ton) registrados em DMR's com destino no município:"
    ]
    df_rsv = pd.DataFrame()    
    df_rsv.index = [
        "Número de DMR's de RSV com origem no município:",
        "Número de DMR's de RSV com destino no município:",
        "Quantidade de RSV (ton) registrados em DMR's com origem no município:",
        "Quantidade de RSV (ton) registrados em DMR's com destino no município:"
    ]
    df_rcc = pd.DataFrame()    
    df_rcc.index = [
        "Número de DMR's de RCC com origem no município:",
        "Número de DMR's de RCC com destino no município:",
        "Quantidade de RCC (ton) registrados em DMR's com origem no município:",
        "Quantidade de RCC (ton) registrados em DMR's com destino no município:"
    ]
    df_rss = pd.DataFrame()    
    df_rss.index = [
        "Número de DMR's de RSS com origem no município:",
        "Número de DMR's de RSS com destino no município:",
        "Quantidade de RSS (ton) registrados em DMR's com origem no município:",
        "Quantidade de RSS (ton) registrados em DMR's com destino no município:"
    ]
    df_rsb = pd.DataFrame()    
    df_rsb.index = [
        "Número de DMR's de RSAE com origem no município:",
        "Número de DMR's de RSAE com destino no município:",
        "Quantidade de RSAE (ton) registrados em DMR's com origem no município:",
        "Quantidade de RSAE (ton) registrados em DMR's com destino no município:"
    ]
    df_rsi = pd.DataFrame()    
    df_rsi.index = [
        "Número de DMR's de RSI com origem no município:",
        "Número de DMR's de RSI com destino no município:",
        "Quantidade de RSI (ton) registrados em DMR's com origem no município:",
        "Quantidade de RSI (ton) registrados em DMR's com destino no município:"
    ]
    df_rst = pd.DataFrame()    
    df_rst.index = [
        "Número de DMR's de RST com origem no município:",
        "Número de DMR's de RST com destino no município:",
        "Quantidade de RST (ton) registrados em DMR's com origem no município:",
        "Quantidade de RST (ton) registrados em DMR's com destino no município:"
    ]
    df_rsm = pd.DataFrame()    
    df_rsm.index = [
        "Número de DMR's de RSM com origem no município:",
        "Número de DMR's de RSM com destino no município:",
        "Quantidade de RSM (ton) registrados em DMR's com origem no município:",
        "Quantidade de RSM (ton) registrados em DMR's com destino no município:"
    ]
    df_rsa = pd.DataFrame()    
    df_rsa.index = [
        "Número de DMR's de RSA com origem no município:",
        "Número de DMR's de RSA com destino no município:",
        "Quantidade de RSA (ton) registrados em DMR's com origem no município:",
        "Quantidade de RSA (ton) registrados em DMR's com destino no município:"
    ]
    df_outros = pd.DataFrame()    
    df_outros.index = [
        "Número de DMR's de outros tipos de resíduos com origem no município:",
        "Número de DMR's de outros tipos de resíduos com destino no município:",
        "Quantidade de outros tipos de resíduos (ton) registrados em DMR's com origem no município:",
        "Quantidade de outros tipos de resíduos (ton) registrados em DMR's com destino no município:"
    ]
    
    # Extração dos dados
    for ano in anos:
        municipio_gerador_rsu = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsu])
        municipio_destinador_rsu = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsu])
        df_rsu[ano] = [municipio_gerador_rsu['declaracao_codigo'].count(), municipio_destinador_rsu['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rsu['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsu['declaracao_item_quantidade'].sum(), grouping=True)]

        municipio_gerador_rsv = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsv])
        municipio_destinador_rsv = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsv])
        df_rsv[ano] = [municipio_gerador_rsv['declaracao_codigo'].count(), municipio_destinador_rsv['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rsv['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsv['declaracao_item_quantidade'].sum(), grouping=True)]
        
        municipio_gerador_rcc = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rcc])
        municipio_destinador_rcc = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rcc])
        df_rcc[ano] = [municipio_gerador_rcc['declaracao_codigo'].count(), municipio_destinador_rcc['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rcc['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rcc['declaracao_item_quantidade'].sum(), grouping=True)]
        
        municipio_gerador_rss = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rss])
        municipio_destinador_rss = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rss])
        df_rss[ano] = [municipio_gerador_rss['declaracao_codigo'].count(), municipio_destinador_rss['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rss['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rss['declaracao_item_quantidade'].sum(), grouping=True)]
        
        municipio_gerador_rsb = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsb])
        municipio_destinador_rsb = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsb])
        df_rsb[ano] = [municipio_gerador_rsb['declaracao_codigo'].count(), municipio_destinador_rsb['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rsb['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsb['declaracao_item_quantidade'].sum(), grouping=True)]
        
        municipio_gerador_rsi = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsi])
        municipio_destinador_rsi = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsi])
        df_rsi[ano] = [municipio_gerador_rsi['declaracao_codigo'].count(), municipio_destinador_rsi['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rsi['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsi['declaracao_item_quantidade'].sum(), grouping=True)]
        
        municipio_gerador_rst = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rst])
        municipio_destinador_rst = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rst])
        df_rst[ano] = [municipio_gerador_rst['declaracao_codigo'].count(), municipio_destinador_rst['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rst['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rst['declaracao_item_quantidade'].sum(), grouping=True)]
        
        municipio_gerador_rsm = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsm])
        municipio_destinador_rsm = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsm])
        df_rsm[ano] = [municipio_gerador_rsm['declaracao_codigo'].count(), municipio_destinador_rsm['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rsm['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsm['declaracao_item_quantidade'].sum(), grouping=True)]
        
        municipio_gerador_rsa = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsa])
        municipio_destinador_rsa = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[rsa])
        df_rsa[ano] = [municipio_gerador_rsa['declaracao_codigo'].count(), municipio_destinador_rsa['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_rsa['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_rsa['declaracao_item_quantidade'].sum(), grouping=True)]
        
        municipio_gerador_outros = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[outros])
        municipio_destinador_outros = pd.read_sql_query("""SELECT * FROM dmr WHERE strftime('%Y', declaracao_data_inicial) = '"""+ano+"""' AND strftime('%Y', declaracao_data_final) = '"""+ano+"""' AND declaracao_item_municipio='"""+municipio+"""' AND declaracao_item_pessoa_tipo in ('Destinador', 'Destinador/Gerador', 'Destinador/Transportador', 'Destinador/Transportador/Gerador') AND declaracao_pessoa_tipo in ('Gerador', 'Gerador/Destinador', 'Gerador/Transportador', 'Gerador/Transportador/Destinador') AND declaracao_item_residuo in (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""", "sqlite:///base_de_dados.db",params=[outros])
        df_outros[ano] = [municipio_gerador_outros['declaracao_codigo'].count(), municipio_destinador_outros['declaracao_codigo'].count(), locale.format_string('%.2f', municipio_gerador_outros['declaracao_item_quantidade'].sum(), grouping=True),locale.format_string('%.2f', municipio_destinador_outros['declaracao_item_quantidade'].sum(), grouping=True)]
        
    df_concat = pd.concat([df_rsu, df_embranco, df_rsv, df_embranco, df_rcc, df_embranco, df_rss, df_embranco, df_rsb, df_embranco, df_rsi, df_embranco, df_rst, df_embranco, df_rsm, df_embranco, df_rsa, df_embranco, df_outros])
    df_concat.to_excel("2-dmr_primeira_aba_planilha_pers/"+municipio+'.xlsx')
